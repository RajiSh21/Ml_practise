# %% [markdown]
# <a href="https://colab.research.google.com/github/RajiSh21/Ml_practise/blob/main/mlpractise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("JEE_Dropout.csv")
df.head()
# Out:
#    jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0           78.95               59.22                59.86         CBSE
# 1           70.06               58.75                64.33        State
# 2           81.07               37.27                60.83         ICSE
# 3           93.32               60.72                69.33         ICSE
# 4           68.72               77.73                82.37         CBSE
#
#    class_12_percent  attempt_count coaching_institute  daily_study_hours  \
# 0             70.09              1            FIITJEE                5.4
# 1             78.00              1            FIITJEE                5.5
# 2             64.36              1            FIITJEE                7.0
# 3             73.21              1            FIITJEE                2.1
# 4             89.02              1              Allen                6.3
#
#   family_income parent_education location_type peer_pressure_level  \
# ...

# %%
plt.hist(df["jee_main_score"])
# Out:
# (array([  20.,   47.,  162.,  382.,  703.,  957., 1037.,  846.,  492.,
#          354.]),
#  array([ 26.62 ,  33.958,  41.296,  48.634,  55.972,  63.31 ,  70.648,
#          77.986,  85.324,  92.662, 100.   ]),
#  <BarContainer object of 10 artists>)
